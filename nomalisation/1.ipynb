# %%
data = [1,4,5,6,7,8]
min_value = min(data);
max_value = max(data);
normalised = [(x-min_value)/(max_value-min_value)for x in data]
print(normalised)
# Out:
# [0.0, 0.42857142857142855, 0.5714285714285714, 0.7142857142857143, 0.8571428571428571, 1.0]

# %%
import numpy as np
data = np.array([10, 20, 30, 40, 50])
normalized = (data - data.min()) / (data.max() - data.min())
print(normalized)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
data = [12,45,332,54,78]

mean = sum(data) / len(data)
std = (sum((x - mean) ** 2 for x in data) / len(data)) ** 0.5

normalized = [(x - mean) / std for x in data]

print(normalized)
# Out:
# [-0.795864494290713, -0.511010608047833, 1.966355008670547, -0.43332318452704766, -0.22615672180495316]

# %%
import numpy as np

data = np.array([10, 20, 30, 40, 50])

normalized = (data - data.mean()) / data.std()

print(normalized)
# Out:
# [-1.41421356 -0.70710678  0.          0.70710678  1.41421356]
